# %% [markdown]
# ## PHY688 - Modelling Project
# ## Author: Paras Sharma (ID#: 115415559)

# %% [markdown]
# ### 1. Modelling a Mock Lens

# %% [markdown]
# #### 1.1 - Fitting a lens model by hand
#
# ![Screenshot 2025-02-12 at 10.35.34 AM.png](<attachment:Screenshot 2025-02-12 at 10.35.34 AM.png>)
#
# TODO: Make the fit better by adjusting the parameters.
#
# ![Screenshot 2025-02-12 at 10.54.45 AM.png](<attachment:Screenshot 2025-02-12 at 10.54.45 AM.png>)

# %% [markdown]
# #### 1.2,3,4 - Intro to lens modeling with lenstronomy
#
# ![1p2_1.png](attachment:1p2_1.png)
#
# ![1p2_2.png](attachment:1p2_2.png)

# %% [markdown]
# The optimal parameters (reduced $χ^2 \approx 1.29$) are:
#
# {
#     'kwargs_lens': [{'theta_E': 0.5551956578002347, 'gamma': 2.116578677965326, 'e1': 0.15880578199861178, 'e2': -0.08340015972167678, 'center_x': -0.07401036106314784, 'center_y': -0.07465972468728424}],
#
# 'kwargs_source': [{'amp': 23973.85942997112, 'R_sersic': 0.14968986774112797, 'n_sersic': 1.0, 'e1': -0.4999813401508132, 'e2': -0.07460764759676357, 'center_x': -0.0238509794427031, 'center_y': 0.17211661975947418}],
#
# 'kwargs_lens_light': [{'amp': 6536.062118561356, 'R_sersic': 0.32697382893622035, 'n_sersic': 4.0, 'e1': 0.15880578199861178, 'e2': -0.08340015972167678, 'center_x': -0.07401036106314784, 'center_y': -0.07465972468728424}]
# }
#
# Thus $θ_E = 0.56$, $γ = 2.12$.

# %%
#TODO: to ask how to get uncertianities on the fit parameters?

# %% [markdown]
# ### 2. Modelling a Real Hubble Space Telescope Image
